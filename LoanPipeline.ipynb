# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv('loan_default.csv')
df
# Out:
#        age    income  loan_amount  credit_score  months_employed  \
# 0       60  61014.98      36757.0         517.0            301.0
# 1       50  70351.80      39433.0         800.0             81.0
# 2       36  60984.73       5541.0         492.0            143.0
# 3       64  69848.88      31678.0         632.0             57.0
# 4       29  70202.16      19344.0         452.0            141.0
# ...    ...       ...          ...           ...              ...
# 14995   29  66216.78      47659.0         716.0            193.0
# 14996   55  52873.19      10003.0         454.0            193.0
# 14997   37  59131.33       8463.0         345.0            129.0
# 14998   62  41661.20       9509.0         410.0            309.0
# 14999   34  41845.92      30866.0         527.0            344.0
#
#        num_credit_lines  interest_rate  loan_term  dti_ratio    education  \
# 0                  18.0          11.30       12.0       0.71  High School
# ...

# %% [markdown]
# # Data Cleaning Steps

# %% [markdown]
# ### 1 — Check Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               15000 non-null  int64
#  1   income            14700 non-null  float64
#  2   loan_amount       15000 non-null  float64
#  3   credit_score      14800 non-null  float64
#  4   months_employed   14750 non-null  float64
#  5   num_credit_lines  14850 non-null  float64
#  6   interest_rate     14820 non-null  float64
#  7   loan_term         15000 non-null  float64
#  8   dti_ratio         15000 non-null  float64
#  9   education         15000 non-null  object
#  10  employment_type   15000 non-null  object
#  11  marital_status    15000 non-null  object
#  12  loan_purpose      14900 non-null  object
#  13  has_mortgage      15000 non-null  object
#  14  has_dependents    15000 non-null  object
#  15  has_cosigner      15000 non-null  object
# ...

# %% [markdown]
# ### 2 — Check Missing Values

# %%
df.isna().sum()
# Out:
# age                   0
# income              300
# loan_amount           0
# credit_score        200
# months_employed     250
# num_credit_lines    150
# interest_rate       180
# loan_term             0
# dti_ratio             0
# education             0
# employment_type       0
# marital_status        0
# loan_purpose        100
# has_mortgage          0
# has_dependents        0
# has_cosigner          0
# default               0
# dtype: int64

# %% [markdown]
# ### 3 — Check Duplicates

# %%
df.drop_duplicates(inplace=True, ignore_index=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 4 — Check Outliers

# %%
from datasist.structdata import detect_outliers

for col in df.select_dtypes(include='number').columns:
    outliers = detect_outliers(data=df, n=0, features=[col])
    print(col)
    print(outliers)
    print('-' * 50)
# Out:
# age
# []
# --------------------------------------------------
# income
# []
# --------------------------------------------------
# loan_amount
# []
# --------------------------------------------------
# credit_score
# []
# --------------------------------------------------
# months_employed
# []
# --------------------------------------------------
# num_credit_lines
# []
# --------------------------------------------------
# interest_rate
# []
# --------------------------------------------------
# loan_term
# []
# --------------------------------------------------
# dti_ratio
# []
# --------------------------------------------------
# default
# []
# --------------------------------------------------

# %% [markdown]
# ### 5 — Check Inconsistent Values

# %%
df.describe().round(2)
# Out:
#             age     income  loan_amount  credit_score  months_employed  \
# count  15000.00   14700.00     15000.00      14800.00         14750.00
# mean      45.49   55173.02     25387.59        573.51           178.21
# std       13.78   20106.86     14086.95        156.72           103.72
# min       22.00  -26292.06      1000.00        300.00             0.00
# 25%       34.00   41557.61     13287.75        440.00            89.00
# 50%       45.00   55188.46     25440.50        575.00           177.00
# 75%       57.00   68874.14     37460.25        707.00           267.00
# max       69.00  131134.35     49996.00        849.00           359.00
#
#        num_credit_lines  interest_rate  loan_term  dti_ratio   default
# count          14850.00       14820.00   15000.00   15000.00  15000.00
# mean               9.98          14.23      35.91       0.50      0.32
# std                5.51           6.23      17.04       0.23      0.47
# ...

# %%
df.describe(include=['object'])
# Out:
#          education employment_type marital_status loan_purpose has_mortgage  \
# count        15000           15000          15000        14900        15000
# unique           4               4              3            5            2
# top     Bachelor's       Full-time        Married         Home           No
# freq          6068            8885           6720         3676         8284
#
#        has_dependents has_cosigner
# count           15000        15000
# unique              2            2
# top                No           No
# freq             8925        10538

# %% [markdown]
# ### 6 — Check Class Balance

# %%
df.loc[df['income'] < 0, 'income'] = np.nan

# %%
print('default (Target)')
print(df['default'].value_counts())
print(df['default'].value_counts(normalize=True).round(2))
print('-' * 50)
# Out:
# default (Target)
# default
# 0    10226
# 1     4774
# Name: count, dtype: int64
# default
# 0    0.68
# 1    0.32
# Name: proportion, dtype: float64
# --------------------------------------------------

# %% [markdown]
# ### 7 — Check Feature Imbalance and Unique Values

# %%
for col in df.select_dtypes(include='object').columns:
    print(col)
    print(df[col].nunique())
    print(df[col].unique())
    print(df[col].value_counts())
    print('-' * 50)
# Out:
# education
# 4
# ['High School' "Bachelor's" "Master's" 'PhD']
# education
# Bachelor's     6068
# High School    5265
# Master's       2645
# PhD            1022
# Name: count, dtype: int64
# --------------------------------------------------
# employment_type
# 4
# ['Full-time' 'Self-employed' 'Unemployed' 'Part-time']
# employment_type
# Full-time        8885
# Self-employed    2754
# Part-time        2262
# Unemployed       1099
# Name: count, dtype: int64
# --------------------------------------------------
# marital_status
# 3
# ['Single' 'Married' 'Divorced']
# marital_status
# Married     6720
# Single      6019
# Divorced    2261
# Name: count, dtype: int64
# --------------------------------------------------
# loan_purpose
# 5
# ['Auto' 'Education' 'Business' 'Personal' 'Home' nan]
# loan_purpose
# Home         3676
# Business     3056
# Auto         2987
# Personal     2907
# Education    2274
# Name: count, dtype: int64
# --------------------------------------------------
# ...

# %% [markdown]
# ### 8 — Handle Class Imbalance
#
# The target has ~69% No Default vs ~31% Default — moderate imbalance.
# We use **SMOTE** inside the pipeline via `imblearn` to oversample the minority class only on training folds, preventing data leakage into the test fold.

# %%
# pip install imbalanced-learn
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Pipeline

# %% [markdown]
# ### Split Data into Input & Output

# %%
x = df.drop('default', axis=1)
y = df['default']

# %% [markdown]
# ### Numerical Pipeline

# %%
num_cols = x.select_dtypes(include='number').columns
num_cols
# Out:
# Index(['age', 'income', 'loan_amount', 'credit_score', 'months_employed',
#        'num_credit_lines', 'interest_rate', 'loan_term', 'dti_ratio'],
#       dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer

num_pipeline = Pipeline(steps=[
    ('Imputer', SimpleImputer(strategy='median')),
    ('Scaling', RobustScaler())
])
num_pipeline
# Out:
# Pipeline(steps=[('Imputer', SimpleImputer(strategy='median')),
#                 ('Scaling', RobustScaler())])

# %% [markdown]
# ### Categorical Pipeline
#
# - OHE Pipeline — for **nominal** columns (no natural order)

# %%
# Nominal columns — no natural order between categories
ohe_cols = ['employment_type', 'marital_status',
            'loan_purpose', 'has_mortgage',
            'has_dependents', 'has_cosigner']
ohe_cols
# Out:
# ['employment_type',
#  'marital_status',
#  'loan_purpose',
#  'has_mortgage',
#  'has_dependents',
#  'has_cosigner']

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')

ohe_pipeline = Pipeline(steps=[
    ('Imputer', SimpleImputer(strategy='most_frequent')),
    ('OHE',     ohe)
])
ohe_pipeline
# Out:
# Pipeline(steps=[('Imputer', SimpleImputer(strategy='most_frequent')),
#                 ('OHE',
#                  OneHotEncoder(drop='first', handle_unknown='ignore',
#                                sparse_output=False))])

# %% [markdown]
# - Ordinal Encoding Pipeline — for **ordinal** columns (natural order exists)
#
# `education` has a clear order: High School < Bachelor's < Master's < PhD
# Using OrdinalEncoder preserves this order numerically so the model can use it.

# %%
# Ordinal column — has a meaningful natural order
ord_cols = ['education']
ord_cols
# Out:
# ['education']

# %%
from sklearn.preprocessing import OrdinalEncoder

oe = OrdinalEncoder(categories=[["High School", "Bachelor's", "Master's", "PhD"]])

ord_pipeline = Pipeline(steps=[
    ('Imputer', SimpleImputer(strategy='most_frequent')),
    ('OE',oe)
])
ord_pipeline
# Out:
# Pipeline(steps=[('Imputer', SimpleImputer(strategy='most_frequent')),
#                 ('OE',
#                  OrdinalEncoder(categories=[['High School', "Bachelor's",
#                                              "Master's", 'PhD']]))])

# %% [markdown]
# ### Assign Columns to Pipelines

# %%
from sklearn.compose import ColumnTransformer

preprocessing = ColumnTransformer(transformers=[
    ('Num Pipeline', num_pipeline, num_cols),
    ('OHE Pipeline', ohe_pipeline, ohe_cols),
    ('Ord Pipeline', ord_pipeline, ord_cols)
], remainder='passthrough')

preprocessing
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Num Pipeline',
#                                  Pipeline(steps=[('Imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('Scaling', RobustScaler())]),
#                                  Index(['age', 'income', 'loan_amount', 'credit_score', 'months_employed',
#        'num_credit_lines', 'interest_rate', 'loan_term', 'dti_ratio'],
#       dtype='object')),
#                                 ('OHE Pipeline',
#                                  Pipeline(steps=[('Imputer',
#                                                   S...
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False))]),
# ...

# %%
x.head()
# Out:
#    age    income  loan_amount  credit_score  months_employed  \
# 0   60  61014.98      36757.0         517.0            301.0
# 1   50  70351.80      39433.0         800.0             81.0
# 2   36  60984.73       5541.0         492.0            143.0
# 3   64  69848.88      31678.0         632.0             57.0
# 4   29  70202.16      19344.0         452.0            141.0
#
#    num_credit_lines  interest_rate  loan_term  dti_ratio    education  \
# 0              18.0          11.30       12.0       0.71  High School
# 1              13.0           5.09       48.0       0.24   Bachelor's
# 2              17.0            NaN       12.0       0.67  High School
# 3               8.0          17.38       48.0       0.22  High School
# 4              10.0          21.13       48.0       0.65   Bachelor's
#
#   employment_type marital_status loan_purpose has_mortgage has_dependents  \
# 0       Full-time         Single         Auto           No             No
# ...

# %% [markdown]
# ### Model Comparison — Cross Validation

# %%
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

models = [
    ('Logistic Regression', LogisticRegression(max_iter=1000)),
    ('KNN',                 KNeighborsClassifier()),
    ('Decision Tree',       DecisionTreeClassifier(random_state=42)),
    ('Random Forest',       RandomForestClassifier(random_state=42)),
    ('XGBoost',             XGBClassifier(verbosity=0, eval_metric='logloss')),
    ('CatBoost',            CatBoostClassifier(verbose=0))
]

for model in models:

    model_pipeline = ImbPipeline(steps=[
        ('Preprocessing', preprocessing),
        ('SMOTE',         SMOTE(random_state=42)),
        ('Model',         model[1])
    ])

    result = cross_validate(model_pipeline, x, y, cv=cv,
                            scoring='accuracy',
                            return_train_score=True, n_jobs=-1)

    print(model[0])
    print('Train Score :', round(result['train_score'].mean() * 100, 2))
    print('Test Score  :', round(result['test_score'].mean()  * 100, 2))
    print('-' * 50)
# Out:
# Logistic Regression
# Train Score : 64.04
# Test Score  : 63.84
# --------------------------------------------------
# KNN
# Train Score : 74.03
# Test Score  : 56.01
# --------------------------------------------------
# Decision Tree
# Train Score : 100.0
# Test Score  : 60.07
# --------------------------------------------------
# Random Forest
# Train Score : 100.0
# Test Score  : 68.05
# --------------------------------------------------
# XGBoost
# Train Score : 91.56
# Test Score  : 67.56
# --------------------------------------------------
# CatBoost
# Train Score : 83.19
# Test Score  : 69.59
# --------------------------------------------------

# %% [markdown]
# ### Model Comparison — Multiple Metrics
#
# Accuracy alone is misleading with imbalanced targets.
# **F1** penalises models that ignore the minority class (defaulters).
# **ROC-AUC** measures how well the model separates the two classes regardless of threshold.

# %%
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

models = [
    ('Logistic Regression', LogisticRegression(max_iter=1000)),
    ('KNN',                 KNeighborsClassifier()),
    ('Decision Tree',       DecisionTreeClassifier(random_state=42)),
    ('Random Forest',       RandomForestClassifier(random_state=42)),
    ('XGBoost',             XGBClassifier(verbosity=0, eval_metric='logloss')),
    ('CatBoost',            CatBoostClassifier(verbose=0))
]

for model in models:

    model_pipeline = ImbPipeline(steps=[
        ('Preprocessing', preprocessing),
        ('SMOTE',         SMOTE(random_state=42)),
        ('Model',         model[1])
    ])

    result = cross_validate(model_pipeline, x, y, cv=cv,
                            scoring=['accuracy', 'f1', 'roc_auc'],
                            return_train_score=True, n_jobs=-1)

    print(model[0])
    print('Train Accuracy :', round(result['train_accuracy'].mean() * 100, 2))
    print('Test  Accuracy :', round(result['test_accuracy'].mean()  * 100, 2))
    print('Test  F1       :', round(result['test_f1'].mean()        * 100, 2))
    print('-' * 50)
# Out:
# Logistic Regression
# Train Accuracy : 64.04
# Test  Accuracy : 63.84
# Test  F1       : 52.6
# Test  ROC-AUC  : 68.69
# --------------------------------------------------
# KNN
# Train Accuracy : 74.03
# Test  Accuracy : 56.01
# Test  F1       : 45.62
# Test  ROC-AUC  : 58.3
# --------------------------------------------------
# Decision Tree
# Train Accuracy : 100.0
# Test  Accuracy : 60.07
# Test  F1       : 41.28
# Test  ROC-AUC  : 55.82
# --------------------------------------------------
# Random Forest
# Train Accuracy : 100.0
# Test  Accuracy : 68.05
# Test  F1       : 44.16
# Test  ROC-AUC  : 69.38
# --------------------------------------------------
# XGBoost
# Train Accuracy : 91.56
# Test  Accuracy : 67.56
# Test  F1       : 42.23
# Test  ROC-AUC  : 67.18
# --------------------------------------------------
# CatBoost
# Train Accuracy : 83.19
# Test  Accuracy : 69.59
# Test  F1       : 42.37
# Test  ROC-AUC  : 69.68
# --------------------------------------------------

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from catboost import CatBoostClassifier

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

param_grid = {
    'Model__depth':         [4, 6, 8, 10],
    'Model__learning_rate': [0.01, 0.05, 0.1, 0.2],
    'Model__l2_leaf_reg':   [1, 3, 5, 10]
}

model_pipeline = ImbPipeline(steps=[
    ('Preprocessing', preprocessing),
    ('SMOTE',         SMOTE(random_state=42)),
    ('Model',         CatBoostClassifier(verbose=0))
])

result = RandomizedSearchCV(model_pipeline, param_grid,
                            cv=cv, scoring='f1',
                            return_train_score=True,
                            n_jobs=-1, random_state=42)

result.fit(x, y)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('Preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('Num '
#                                                                                'Pipeline',
#                                                                                Pipeline(steps=[('Imputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('Scaling',
#                                                                                                 RobustScaler())]),
# ...

# %%
result.cv_results_['mean_test_score']
# Out:
# array([0.43874689, 0.41818976, 0.44518383, 0.45231734, 0.42114897,
#        0.44493673, 0.443987  , 0.45417815, 0.42320285, 0.41695972])

# %%
result.best_score_ * 100
# Out:
# np.float64(45.41781507783341)

# %%
result.best_params_
# Out:
# {'Model__learning_rate': 0.01, 'Model__l2_leaf_reg': 10, 'Model__depth': 4}

# %% [markdown]
# ### Train Final Model

# %%
# Replace the param values below with your result.best_params_ output
catboost_pipeline = ImbPipeline(steps=[
    ('Preprocessing', preprocessing),
    ('SMOTE',         SMOTE(random_state=42)),
    ('Model',         CatBoostClassifier(learning_rate=0.1,
                                         l2_leaf_reg=3,
                                         depth=6,
                                         verbose=0))
])

catboost_pipeline.fit(x, y)
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Num Pipeline',
#                                                   Pipeline(steps=[('Imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('Scaling',
#                                                                    RobustScaler())]),
#                                                   Index(['age', 'income', 'loan_amount', 'credit_score', 'months_employed',
#        'num_credit_lines', 'interest_rate', 'loan_term', 'dti_ratio'],
#       dtype='object')),
#                                                  ('OHE Pipel...
#                                                    'marital_status',
#                                                    'loan_purpose',
# ...

# %%
df.head(1)
# Out:
#    age    income  loan_amount  credit_score  months_employed  \
# 0   60  61014.98      36757.0         517.0            301.0
#
#    num_credit_lines  interest_rate  loan_term  dti_ratio    education  \
# 0              18.0           11.3       12.0       0.71  High School
#
#   employment_type marital_status loan_purpose has_mortgage has_dependents  \
# 0       Full-time         Single         Auto           No             No
#
#   has_cosigner  default
# 0           No        1

# %%
# Test on first row — 0 = No Default, 1 = Default
catboost_pipeline.predict(x.head(1))[0]
# Out:
# np.int64(1)

# %%
import joblib

joblib.dump(catboost_pipeline, 'catboost_loan.pkl')
# Out:
# ['catboost_loan.pkl']

# %% [markdown]
# # Deployment

# %%
import streamlit as st

# %%
# %%writefile loan_default_app.py

import pandas as pd
import streamlit as st
import joblib
from sklearn.preprocessing import RobustScaler, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from catboost import CatBoostClassifier

st.set_page_config(layout='wide', page_title='Loan Default Prediction')

html_title = '''<h1 style="color:white;text-align:center;"> Loan Default Prediction </h1>'''
st.markdown(html_title, unsafe_allow_html=True)

df = pd.read_csv('loan_default.csv')
st.dataframe(df.head())

age              = st.sidebar.slider('Age', min_value=22, max_value=70, step=1)
income           = st.text_input('Annual Income', '')
loan_amount      = st.text_input('Loan Amount', '')
credit_score     = st.sidebar.slider('Credit Score', min_value=300, max_value=850, step=1)
months_employed  = st.text_input('Months Employed', '')
num_credit_lines = st.text_input('Number of Credit Lines', '')
interest_rate    = st.text_input('Interest Rate (%)', '')
loan_term        = st.sidebar.selectbox('Loan Term (months)', [12, 24, 36, 48, 60])
dti_ratio        = st.text_input('Debt-to-Income Ratio', '')
education        = st.sidebar.selectbox('Education', ["High School", "Bachelor's", "Master's", "PhD"])
employment_type  = st.sidebar.selectbox('Employment Type', df['employment_type'].unique())
marital_status   = st.sidebar.selectbox('Marital Status', df['marital_status'].unique())
loan_purpose     = st.selectbox('Loan Purpose', df['loan_purpose'].unique())
has_mortgage     = st.selectbox('Has Mortgage', ['Yes', 'No'])
has_dependents   = st.selectbox('Has Dependents', ['Yes', 'No'])
has_cosigner     = st.selectbox('Has Co-Signer', ['Yes', 'No'])

ml_model = joblib.load('catboost_loan.pkl')

if st.button('Predict Default Risk'):

    new_data = pd.DataFrame(columns=df.drop('default', axis=1).columns,
                            data=[[age, income, loan_amount, credit_score,
                                   months_employed, num_credit_lines, interest_rate,
                                   loan_term, dti_ratio, education, employment_type,
                                   marital_status, loan_purpose, has_mortgage,
                                   has_dependents, has_cosigner]])

    prediction = ml_model.predict(new_data)[0]

    if prediction == 1:
        st.error('High Risk: This loan is likely to DEFAULT')
    else:
        st.success('Low Risk: This loan is likely to be REPAID')
# Out:
# Overwriting loan_default_app.py

# %%
! streamlit run loan_default_app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.1.3:8501
# Exception ignored in: <function ResourceTracker.__del__ at 0x110d99b20>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10f1c1b20>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
# ...

# %%
import pipreqs
! pipreqs
# ! pipreqs --force ./
